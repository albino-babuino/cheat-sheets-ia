# %% [markdown]
# # Markdown - Guía de Sintaxis
#
# Este notebook contiene una guía completa de la sintaxis Markdown para formatear texto.

# %% [markdown]
# ## Encabezados

# %% [raw]
# ```markdown
# # Encabezado 1 (H1)
# ## Encabezado 2 (H2)
# ### Encabezado 3 (H3)
# #### Encabezado 4 (H4)
# ##### Encabezado 5 (H5)
# ###### Encabezado 6 (H6)
# ```

# %% [markdown]
# También puedes usar sintaxis alternativa:

# %% [raw]
# ```markdown
# Encabezado 1
# ===========
#
# Encabezado 2
# ------------
# ```

# %% [markdown]
# ## Énfasis

# %% [raw]
# ```markdown
# *texto en cursiva*
# _texto en cursiva_
#
# **texto en negrita**
# __texto en negrita__
#
# ***texto en negrita y cursiva***
# ___texto en negrita y cursiva___
#
# ~~texto tachado~~
#
# `texto en código inline`
# ```

# %% [markdown]
# ## Listas

# %% [markdown]
# ### Listas no ordenadas

# %% [raw]
# ```markdown
# - Item 1
# - Item 2
#   - Subitem 2.1
#   - Subitem 2.2
# - Item 3
#
# * También puedes usar asteriscos
# + O signos más
# ```

# %% [markdown]
# ### Listas ordenadas

# %% [raw]
# ```markdown
# 1. Primer item
# 2. Segundo item
# 3. Tercer item
#    1. Subitem 3.1
#    2. Subitem 3.2
# ```

# %% [markdown]
# ## Enlaces

# %% [raw]
# ```markdown
# [Texto del enlace](https://ejemplo.com)
# [Texto del enlace](https://ejemplo.com "Título opcional")
# [Enlace con referencia][referencia]
#
# [referencia]: https://ejemplo.com
#
# <https://ejemplo.com>  # Enlace directo
# <correo@ejemplo.com>   # Enlace de email
# ```

# %% [markdown]
# ## Imágenes

# %% [raw]
# ```markdown
# ![Texto alternativo](ruta/imagen.png)
# ![Texto alternativo](ruta/imagen.png "Título opcional")
# ![Imagen con referencia][imagen-ref]
#
# [imagen-ref]: ruta/imagen.png "Título"
# ```

# %% [markdown]
# ## Código

# %% [raw]
# ```markdown
# Usa `código inline` dentro del texto.
# ```

# %% [raw]
# ```markdown
# ```python
# def hola():
#     print("Hola, mundo!")
# ```
# ```

# %% [markdown]
# ## Citas (Blockquotes)

# %% [raw]
# ```markdown
# > Esta es una cita.
# > Puede tener múltiples líneas.
#
# > Cita con múltiples párrafos.
# >
# > Segundo párrafo de la cita.
#
# > Cita anidada
# >> Cita dentro de otra cita
# ```

# %% [markdown]
# ## Tablas

# %% [raw]
# ```markdown
# | Columna 1 | Columna 2 | Columna 3 |
# |-----------|-----------|----------|
# | Dato 1    | Dato 2    | Dato 3   |
# | Dato 4    | Dato 5    | Dato 6   |
#
# # Alineación
# | Izquierda | Centro | Derecha |
# |:----------|:------:|--------:|
# | Texto     | Texto  | Texto   |
# ```

# %% [markdown]
# ## Líneas horizontales

# %% [raw]
# ```markdown
# ---
# ***
# ___
# - - -
# ```

# %% [markdown]
# ## HTML
#
# Markdown permite HTML inline:

# %% [raw]
# ```markdown
# <strong>Texto en negrita</strong>
# <em>Texto en cursiva</em>
# <code>código</code>
# <div style="color: red;">Texto rojo</div>
# ```

# %% [markdown]
# ## Caracteres de escape
#
# Usa backslash para escapar caracteres especiales:

# %% [raw]
# ```markdown
# \   # Backslash
# \`   # Backtick
# \*   # Asterisco
# \_   # Guion bajo
# \#   # Hash
# \+   # Signo más
# \-   # Guion
# \.   # Punto
# \!   # Exclamación
# ```

# %% [markdown]
# ## Listas de tareas (Task Lists)

# %% [raw]
# ```markdown
# - [x] Tarea completada
# - [ ] Tarea pendiente
# - [x] Otra tarea completada
# - [ ] Otra tarea pendiente
# ```

# %% [markdown]
# ## Emojis
#
# Muchos procesadores de Markdown soportan emojis:

# %% [raw]
# ```markdown
# :smile: :heart: :rocket: :thumbsup:
#
# O directamente:
# 😀 ❤️ 🚀 👍
# ```

# %% [markdown]
# ## Ejemplos Prácticos

# %% [markdown]
# ### Documentación de código

# %% [raw]
# ```markdown
# # Mi Proyecto
#
# ## Instalación
#
# ```bash
# pip install mi-proyecto
# ```
#
# ## Uso
#
# ```python
# from mi_proyecto import MiClase
#
# obj = MiClase()
# obj.metodo()
# ```
# ```

# %% [markdown]
# ### README típico

# %% [raw]
# ```markdown
# # Nombre del Proyecto
#
# Breve descripción del proyecto.
#
# ## Características
#
# - Característica 1
# - Característica 2
# - Característica 3
#
# ## Instalación
#
# Ver [INSTALL.md](INSTALL.md) para instrucciones detalladas.
#
# ## Licencia
#
# Este proyecto está bajo la licencia MIT.
# ```

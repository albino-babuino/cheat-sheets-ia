# %% [markdown]
# # Markdown - Guía de SintaxisEste notebook contiene una guía completa de la sintaxis Markdown para formatear texto.

# %% [markdown]
# ## Encabezados```markdown# Encabezado 1 (H1)## Encabezado 2 (H2)### Encabezado 3 (H3)#### Encabezado 4 (H4)##### Encabezado 5 (H5)###### Encabezado 6 (H6)```También puedes usar sintaxis alternativa:```markdownEncabezado 1===========Encabezado 2------------```

# %% [markdown]
# ## Énfasis```markdown*texto en cursiva*_texto en cursiva_**texto en negrita**__texto en negrita__***texto en negrita y cursiva***___texto en negrita y cursiva___~~texto tachado~~`texto en código inline````

# %% [markdown]
# ## Listas### Listas no ordenadas```markdown- Item 1- Item 2  - Subitem 2.1  - Subitem 2.2- Item 3* También puedes usar asteriscos+ O signos más```### Listas ordenadas```markdown1. Primer item2. Segundo item3. Tercer item   1. Subitem 3.1   2. Subitem 3.2```

# %% [markdown]
# ## Enlaces```markdown[Texto del enlace](https://ejemplo.com)[Texto del enlace](https://ejemplo.com "Título opcional")[Enlace con referencia][referencia][referencia]: https://ejemplo.com<https://ejemplo.com>  # Enlace directo<correo@ejemplo.com>   # Enlace de email```

# %% [markdown]
# ## Imágenes```markdown![Texto alternativo](ruta/imagen.png)![Texto alternativo](ruta/imagen.png "Título opcional")![Imagen con referencia][imagen-ref][imagen-ref]: ruta/imagen.png "Título"```

# %% [markdown]
# ## Código### Código inline```markdownUsa `código inline` dentro del texto.```### Bloques de código````markdown```pythondef hola():    print("Hola, mundo!")```````Puedes especificar el lenguaje para resaltado de sintaxis:- `python`- `javascript`- `bash`- `json`- `markdown`- Y muchos más...

# %% [markdown]
# ## Citas (Blockquotes)```markdown> Esta es una cita.> Puede tener múltiples líneas.> Cita con múltiples párrafos.>> Segundo párrafo de la cita.> Cita anidada>> Cita dentro de otra cita```

# %% [markdown]
# ## Tablas```markdown| Columna 1 | Columna 2 | Columna 3 ||-----------|-----------|----------|| Dato 1    | Dato 2    | Dato 3   || Dato 4    | Dato 5    | Dato 6   |# Alineación| Izquierda | Centro | Derecha ||:----------|:------:|--------:|| Texto     | Texto  | Texto   |```

# %% [markdown]
# ## Líneas horizontales```markdown---***___- - -```

# %% [markdown]
# ## HTMLMarkdown permite HTML inline:```markdown<strong>Texto en negrita</strong><em>Texto en cursiva</em><code>código</code><div style="color: red;">Texto rojo</div>```

# %% [markdown]
# ## Caracteres de escapeUsa backslash para escapar caracteres especiales:```markdown\   # Backslash\`   # Backtick\*   # Asterisco\_   # Guion bajo\#   # Hash\+   # Signo más\-   # Guion\.   # Punto\!   # Exclamación```

# %% [markdown]
# ## Listas de tareas (Task Lists)```markdown- [x] Tarea completada- [ ] Tarea pendiente- [x] Otra tarea completada- [ ] Otra tarea pendiente```

# %% [markdown]
# ## EmojisMuchos procesadores de Markdown soportan emojis:```markdown:smile: :heart: :rocket: :thumbsup:O directamente:😀 ❤️ 🚀 👍```

# %% [markdown]
# ## Ejemplos Prácticos### Documentación de código````markdown# Mi Proyecto## Instalación```bashpip install mi-proyecto```## Uso```pythonfrom mi_proyecto import MiClaseobj = MiClase()obj.metodo()```````### README típico```markdown# Nombre del ProyectoBreve descripción del proyecto.## Características- Característica 1- Característica 2- Característica 3## InstalaciónVer [INSTALL.md](INSTALL.md) para instrucciones detalladas.## LicenciaEste proyecto está bajo la licencia MIT.```
